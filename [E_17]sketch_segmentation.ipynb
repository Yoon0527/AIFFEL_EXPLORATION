# %% [markdown]
# # [E-17] 난 스케치를 할 테니 너는 채색을 하거라

# %% [markdown]
# ## 프로젝트: Segmentaion map으로 도로 이미지 만들기
# * 루브릭
#   * 데이터 분석 과정 및 한 가지 이상의 augmentation을 포함한 데이터셋 구축 과정이 체계적으로 제시되었다.
#   * U-Net generator, discriminator 모델 구현이 완료되어 train_step이 안정적으로 진행됨을 확인하였다.
#   * 10 epoch 이상의 학습을 진행한 후 최종 테스트 결과에서 진행한 epoch 수에 걸맞는 정도의 품질을 확인하였다.

# %%
# jupyter notebook에 cityscapes.zip의 업로드가 너무 오래 걸림...
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
import glob
import os

train = glob.glob('/content/drive/MyDrive/aiffel/cityscapes/train/*.jpg')
val = glob.glob('/content/drive/MyDrive/aiffel/cityscapes/val/*.jpg')

print('number of train examples : ', len(train))
print('number of validation examples : ', len(val))
# Out:
# number of train examples :  1000
# number of validation examples :  5

# %% [markdown]
# ![스크린샷 2022-03-20 오후 5.22.57.png](data:image/png;base64,...)

# %% [markdown]
# cv2.imshow 오류가 생김.
#
# from google.colab.patches import cv2_imshow 코드를 추가해 오류 해결.

# %%
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
import matplotlib.pyplot as plt

for i in range(10):
  img = cv2.imread(train[i], cv2.IMREAD_COLOR)
  cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FC2FDB50150>
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FC2FCAB6B90>
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FC2FDB50510>
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FC2FCAB6D10>
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FC2FCAB6B90>
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FC2FCAB6DD0>
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FC2FCAB6CD0>
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FC2FCAB6E50>
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FC2FCAB6B90>
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FC2FDB4F5D0>

# %%
print(img.shape)
# Out:
# (256, 512, 3)

# %%
import tensorflow as tf

def normalize(x):
  x = tf.cast(x, tf.float32)
  return (x/127.5) - 1

def denormalize(x):
  x = (x+1)*127.5
  x = x.numpy()
  return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

f = train[0]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %%
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]

# %%
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_colored = apply_augmentation(sketch, colored)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
from tensorflow import data

def get_train(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored) 
    return sketch, colored

# %%
train_images = data.Dataset.list_files('/content/drive/MyDrive/aiffel/cityscapes/train/'+'*.jpg')
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))

# %%
from tensorflow.keras import layers, Input, Model
class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  encode_block (EncodeBlock)     (None, 128, 128, 64  3072        ['input_1[0][0]']
#                                 )
#
#  encode_block_1 (EncodeBlock)   (None, 64, 64, 128)  131584      ['encode_block[0][0]']
#
#  encode_block_2 (EncodeBlock)   (None, 32, 32, 256)  525312      ['encode_block_1[0][0]']
#
#  encode_block_3 (EncodeBlock)   (None, 16, 16, 512)  2099200     ['encode_block_2[0][0]']
#
#  encode_block_4 (EncodeBlock)   (None, 8, 8, 512)    4196352     ['encode_block_3[0][0]']
#
#  encode_block_5 (EncodeBlock)   (None, 4, 4, 512)    4196352     ['encode_block_4[0][0]']
#
#  encode_block_6 (EncodeBlock)   (None, 2, 2, 512)    4196352     ['encode_block_5[0][0]']
#
#  encode_block_7 (EncodeBlock)   (None, 1, 1, 512)    4196352     ['encode_block_6[0][0]']
#
#  decode_block (DecodeBlock)     (None, 2, 2, 512)    4196352     ['encode_block_7[0][0]']
#
#  concatenate (Concatenate)      (None, 2, 2, 1024)   0           ['decode_block[0][0]',
#                                                                   'encode_block_6[0][0]']
#
#  decode_block_1 (DecodeBlock)   (None, 4, 4, 512)    8390656     ['concatenate[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 4, 4, 1024)   0           ['decode_block_1[0][0]',
#                                                                   'encode_block_5[0][0]']
#
#  decode_block_2 (DecodeBlock)   (None, 8, 8, 512)    8390656     ['concatenate_1[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 8, 8, 1024)   0           ['decode_block_2[0][0]',
#                                                                   'encode_block_4[0][0]']
#
#  decode_block_3 (DecodeBlock)   (None, 16, 16, 512)  8390656     ['concatenate_2[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 16, 16, 1024  0           ['decode_block_3[0][0]',
#                                 )                                 'encode_block_3[0][0]']
#
#  decode_block_4 (DecodeBlock)   (None, 32, 32, 256)  4195328     ['concatenate_3[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 32, 32, 512)  0           ['decode_block_4[0][0]',
#                                                                   'encode_block_2[0][0]']
#
#  decode_block_5 (DecodeBlock)   (None, 64, 64, 128)  1049088     ['concatenate_4[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 64, 64, 256)  0           ['decode_block_5[0][0]',
#                                                                   'encode_block_1[0][0]']
#
#  decode_block_6 (DecodeBlock)   (None, 128, 128, 64  262400      ['concatenate_5[0][0]']
#                                 )
#
#  concatenate_6 (Concatenate)    (None, 128, 128, 12  0           ['decode_block_6[0][0]',
#                                 8)                                'encode_block[0][0]']
#
#  conv2d_transpose_7 (Conv2DTran  (None, 256, 256, 3)  6144       ['concatenate_6[0][0]']
#  spose)
#
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()

# %%
Discriminator().get_summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  input_3 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  concatenate_7 (Concatenate)    (None, 256, 256, 6)  0           ['input_2[0][0]',
#                                                                   'input_3[0][0]']
#
#  disc_block (DiscBlock)         (None, 128, 128, 64  6144        ['concatenate_7[0][0]']
#                                 )
#
#  disc_block_1 (DiscBlock)       (None, 64, 64, 128)  131584      ['disc_block[0][0]']
#
#  disc_block_2 (DiscBlock)       (None, 32, 32, 256)  525312      ['disc_block_1[0][0]']
#
#  disc_block_3 (DiscBlock)       (None, 31, 31, 512)  2099200     ['disc_block_2[0][0]']
#
#  disc_block_4 (DiscBlock)       (None, 30, 30, 1)    8192        ['disc_block_3[0][0]']
#
#  activation (Activation)        (None, 30, 30, 1)    0           ['disc_block_4[0][0]']
#
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

# %%
EPOCHS = 100

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
                
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 10 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# EPOCH[61] - STEP[10]
# Generator_loss:2.2871
# L1_loss:0.1494
# Discriminator_loss:0.2870
#
# EPOCH[61] - STEP[20]
# Generator_loss:2.3486
# L1_loss:0.1779
# Discriminator_loss:0.5750
#
# EPOCH[61] - STEP[30]
# Generator_loss:0.9671
# L1_loss:0.1190
# Discriminator_loss:0.7983
#
# EPOCH[61] - STEP[40]
# Generator_loss:2.8108
# L1_loss:0.1482
# Discriminator_loss:0.1675
#
# EPOCH[61] - STEP[50]
# Generator_loss:1.6544
# L1_loss:0.1446
# Discriminator_loss:0.3866
#
# EPOCH[61] - STEP[60]
# Generator_loss:1.1859
# L1_loss:0.1406
# Discriminator_loss:0.6581
#
# EPOCH[61] - STEP[70]
# Generator_loss:1.1362
# L1_loss:0.1389
# Discriminator_loss:0.7726
#
# EPOCH[61] - STEP[80]
# Generator_loss:3.4006
# L1_loss:0.1289
# Discriminator_loss:0.8362
#
# EPOCH[61] - STEP[90]
# Generator_loss:3.7510
# L1_loss:0.1460
# Discriminator_loss:0.2057
#
# EPOCH[61] - STEP[100]
# Generator_loss:1.5801
# L1_loss:0.1109
# Discriminator_loss:1.0464
#
# EPOCH[61] - STEP[110]
# Generator_loss:2.2249
# L1_loss:0.1413
# Discriminator_loss:0.4036
#
# EPOCH[61] - STEP[120]
# Generator_loss:2.6113
# L1_loss:0.1415
# Discriminator_loss:0.1493
#
# EPOCH[61] - STEP[130]
# Generator_loss:2.5896
# L1_loss:0.1168
# Discriminator_loss:0.4688
#
# EPOCH[61] - STEP[140]
# Generator_loss:4.0765
# L1_loss:0.1433
# Discriminator_loss:0.8379
#
# EPOCH[61] - STEP[150]
# Generator_loss:3.3900
# L1_loss:0.1096
# Discriminator_loss:0.5702
#
# EPOCH[61] - STEP[160]
# Generator_loss:1.1201
# L1_loss:0.1673
# Discriminator_loss:0.6649
#
# EPOCH[61] - STEP[170]
# Generator_loss:3.7789
# L1_loss:0.1240
# Discriminator_loss:0.5282
#
# EPOCH[61] - STEP[180]
# Generator_loss:3.9710
# L1_loss:0.1542
# Discriminator_loss:0.3936
#
# EPOCH[61] - STEP[190]
# Generator_loss:3.9861
# L1_loss:0.1181
# Discriminator_loss:1.0024
#
# EPOCH[61] - STEP[200]
# Generator_loss:2.4445
# L1_loss:0.1457
# Discriminator_loss:0.3085
#
# EPOCH[61] - STEP[210]
# Generator_loss:3.8406
# L1_loss:0.1332
# Discriminator_loss:0.2456
#
# EPOCH[61] - STEP[220]
# Generator_loss:1.0470
# L1_loss:0.1525
# Discriminator_loss:0.5993
#
# EPOCH[61] - STEP[230]
# Generator_loss:4.0820
# L1_loss:0.1329
# Discriminator_loss:0.4891
#
# EPOCH[61] - STEP[240]
# Generator_loss:1.6899
# L1_loss:0.1804
# Discriminator_loss:0.3601
#
# EPOCH[61] - STEP[250]
# Generator_loss:2.1920
# L1_loss:0.1308
# Discriminator_loss:0.3289
#
# EPOCH[62] - STEP[10]
# Generator_loss:1.2356
# L1_loss:0.1168
# Discriminator_loss:0.6665
#
# EPOCH[62] - STEP[20]
# Generator_loss:4.3229
# L1_loss:0.1543
# Discriminator_loss:0.4851
#
# EPOCH[62] - STEP[30]
# Generator_loss:2.5520
# L1_loss:0.1336
# Discriminator_loss:0.3510
#
# EPOCH[62] - STEP[40]
# Generator_loss:2.1084
# L1_loss:0.1307
# Discriminator_loss:0.4023
#
# EPOCH[62] - STEP[50]
# Generator_loss:4.3499
# L1_loss:0.1258
# Discriminator_loss:0.2975
#
# EPOCH[62] - STEP[60]
# Generator_loss:3.9647
# L1_loss:0.1925
# Discriminator_loss:0.0490
#
# EPOCH[62] - STEP[70]
# Generator_loss:4.7693
# L1_loss:0.1443
# Discriminator_loss:0.2094
#
# EPOCH[62] - STEP[80]
# Generator_loss:1.7061
# L1_loss:0.1252
# Discriminator_loss:0.3694
#
# EPOCH[62] - STEP[90]
# Generator_loss:4.6670
# L1_loss:0.1358
# Discriminator_loss:0.2238
#
# EPOCH[62] - STEP[100]
# Generator_loss:3.2811
# L1_loss:0.1453
# Discriminator_loss:0.1437
#
# EPOCH[62] - STEP[110]
# Generator_loss:0.9264
# L1_loss:0.1371
# Discriminator_loss:0.9655
#
# EPOCH[62] - STEP[120]
# Generator_loss:4.4185
# L1_loss:0.1448
# Discriminator_loss:0.5844
#
# EPOCH[62] - STEP[130]
# Generator_loss:3.1309
# L1_loss:0.1345
# Discriminator_loss:0.5358
#
# EPOCH[62] - STEP[140]
# Generator_loss:5.7478
# L1_loss:0.1385
# Discriminator_loss:0.2679
#
# EPOCH[62] - STEP[150]
# Generator_loss:1.5950
# L1_loss:0.1661
# Discriminator_loss:0.4022
#
# EPOCH[62] - STEP[160]
# Generator_loss:1.1225
# L1_loss:0.1353
# Discriminator_loss:0.6766
#
# EPOCH[62] - STEP[170]
# Generator_loss:0.2364
# L1_loss:0.1403
# Discriminator_loss:2.0228
#
# EPOCH[62] - STEP[180]
# Generator_loss:2.6537
# L1_loss:0.1510
# Discriminator_loss:0.3428
#
# EPOCH[62] - STEP[190]
# Generator_loss:1.5370
# L1_loss:0.1233
# Discriminator_loss:0.4369
#
# EPOCH[62] - STEP[200]
# Generator_loss:2.4345
# L1_loss:0.1346
# Discriminator_loss:0.2886
#
# EPOCH[62] - STEP[210]
# Generator_loss:1.5233
# L1_loss:0.1269
# Discriminator_loss:0.5191
#
# EPOCH[62] - STEP[220]
# Generator_loss:3.0479
# L1_loss:0.1485
# Discriminator_loss:0.1551
#
# EPOCH[62] - STEP[230]
# Generator_loss:3.4339
# L1_loss:0.1484
# Discriminator_loss:0.1264
#
# EPOCH[62] - STEP[240]
# Generator_loss:3.7246
# L1_loss:0.1554
# Discriminator_loss:0.0593
#
# EPOCH[62] - STEP[250]
# Generator_loss:1.4188
# L1_loss:0.1399
# Discriminator_loss:0.6021
#
# EPOCH[63] - STEP[10]
# Generator_loss:2.6939
# L1_loss:0.1179
# Discriminator_loss:0.4417
#
# EPOCH[63] - STEP[20]
# Generator_loss:3.2410
# L1_loss:0.1208
# Discriminator_loss:0.7045
#
# EPOCH[63] - STEP[30]
# Generator_loss:2.5276
# L1_loss:0.1824
# Discriminator_loss:0.1828
#
# EPOCH[63] - STEP[40]
# Generator_loss:2.4036
# L1_loss:0.1165
# Discriminator_loss:0.3771
#
# EPOCH[63] - STEP[50]
# Generator_loss:3.9914
# L1_loss:0.1335
# Discriminator_loss:0.4879
#
# EPOCH[63] - STEP[60]
# Generator_loss:2.7451
# L1_loss:0.1954
# Discriminator_loss:0.1130
#
# EPOCH[63] - STEP[70]
# Generator_loss:0.7273
# L1_loss:0.1437
# Discriminator_loss:0.9721
#
# EPOCH[63] - STEP[80]
# Generator_loss:3.4415
# L1_loss:0.1207
# Discriminator_loss:0.4406
#
# EPOCH[63] - STEP[90]
# Generator_loss:0.6540
# L1_loss:0.1368
# Discriminator_loss:1.2352
#
# EPOCH[63] - STEP[100]
# Generator_loss:1.9135
# L1_loss:0.1158
# Discriminator_loss:0.3278
#
# EPOCH[63] - STEP[110]
# Generator_loss:3.3986
# L1_loss:0.1238
# Discriminator_loss:0.7475
#
# EPOCH[63] - STEP[120]
# Generator_loss:0.9473
# L1_loss:0.1550
# Discriminator_loss:0.7601
#
# EPOCH[63] - STEP[130]
# Generator_loss:3.5261
# L1_loss:0.1851
# Discriminator_loss:0.1176
#
# EPOCH[63] - STEP[140]
# Generator_loss:2.1998
# L1_loss:0.1290
# Discriminator_loss:0.2955
#
# EPOCH[63] - STEP[150]
# Generator_loss:2.8575
# L1_loss:0.1368
# Discriminator_loss:0.1962
#
# EPOCH[63] - STEP[160]
# Generator_loss:1.3989
# L1_loss:0.1303
# Discriminator_loss:0.4383
#
# EPOCH[63] - STEP[170]
# Generator_loss:3.8905
# L1_loss:0.1974
# Discriminator_loss:0.1120
#
# EPOCH[63] - STEP[180]
# Generator_loss:4.1575
# L1_loss:0.1432
# Discriminator_loss:0.0964
#
# EPOCH[63] - STEP[190]
# Generator_loss:2.3778
# L1_loss:0.1433
# Discriminator_loss:0.2371
#
# EPOCH[63] - STEP[200]
# Generator_loss:4.2157
# L1_loss:0.1329
# Discriminator_loss:0.2371
#
# EPOCH[63] - STEP[210]
# Generator_loss:4.1820
# L1_loss:0.1584
# Discriminator_loss:0.0760
#
# EPOCH[63] - STEP[220]
# Generator_loss:3.3652
# L1_loss:0.1465
# Discriminator_loss:0.3171
#
# EPOCH[63] - STEP[230]
# Generator_loss:3.5173
# L1_loss:0.1242
# Discriminator_loss:0.2331
#
# EPOCH[63] - STEP[240]
# Generator_loss:3.3856
# L1_loss:0.1330
# Discriminator_loss:0.1782
#
# EPOCH[63] - STEP[250]
# Generator_loss:1.7369
# L1_loss:0.1336
# Discriminator_loss:0.4506
#
# EPOCH[64] - STEP[10]
# Generator_loss:4.7155
# L1_loss:0.1327
# Discriminator_loss:2.2324
#
# EPOCH[64] - STEP[20]
# Generator_loss:0.7960
# L1_loss:0.1361
# Discriminator_loss:0.9186
#
# EPOCH[64] - STEP[30]
# Generator_loss:0.5940
# L1_loss:0.1482
# Discriminator_loss:1.4939
#
# EPOCH[64] - STEP[40]
# Generator_loss:1.0454
# L1_loss:0.1160
# Discriminator_loss:0.8230
#
# EPOCH[64] - STEP[50]
# Generator_loss:0.6380
# L1_loss:0.1586
# Discriminator_loss:1.3041
#
# EPOCH[64] - STEP[60]
# Generator_loss:2.6448
# L1_loss:0.1384
# Discriminator_loss:0.2306
#
# EPOCH[64] - STEP[70]
# Generator_loss:2.7229
# L1_loss:0.1434
# Discriminator_loss:0.1858
#
# EPOCH[64] - STEP[80]
# Generator_loss:2.2596
# L1_loss:0.1057
# Discriminator_loss:0.3034
#
# EPOCH[64] - STEP[90]
# Generator_loss:2.5765
# L1_loss:0.1504
# Discriminator_loss:0.2400
#
# EPOCH[64] - STEP[100]
# Generator_loss:3.9055
# L1_loss:0.1325
# Discriminator_loss:0.1006
#
# EPOCH[64] - STEP[110]
# Generator_loss:6.2431
# L1_loss:0.1677
# Discriminator_loss:0.3459
#
# EPOCH[64] - STEP[120]
# Generator_loss:5.1982
# L1_loss:0.1396
# Discriminator_loss:0.2258
#
# EPOCH[64] - STEP[130]
# Generator_loss:1.8118
# L1_loss:0.1325
# Discriminator_loss:0.3273
#
# EPOCH[64] - STEP[140]
# Generator_loss:3.8280
# L1_loss:0.1889
# Discriminator_loss:0.1451
#
# EPOCH[64] - STEP[150]
# Generator_loss:1.6665
# L1_loss:0.1342
# Discriminator_loss:0.4194
#
# EPOCH[64] - STEP[160]
# Generator_loss:1.5267
# L1_loss:0.1585
# Discriminator_loss:0.4159
#
# EPOCH[64] - STEP[170]
# Generator_loss:2.6386
# L1_loss:0.1758
# Discriminator_loss:0.1326
#
# EPOCH[64] - STEP[180]
# Generator_loss:3.6730
# L1_loss:0.1194
# Discriminator_loss:1.6969
#
# EPOCH[64] - STEP[190]
# Generator_loss:3.2282
# L1_loss:0.1425
# Discriminator_loss:0.2750
#
# EPOCH[64] - STEP[200]
# Generator_loss:3.9660
# L1_loss:0.1303
# Discriminator_loss:1.2374
#
# EPOCH[64] - STEP[210]
# Generator_loss:0.9549
# L1_loss:0.1521
# Discriminator_loss:0.9579
#
# EPOCH[64] - STEP[220]
# Generator_loss:2.1409
# L1_loss:0.1503
# Discriminator_loss:0.3350
#
# EPOCH[64] - STEP[230]
# Generator_loss:1.8892
# L1_loss:0.1223
# Discriminator_loss:0.3749
#
# EPOCH[64] - STEP[240]
# Generator_loss:4.2304
# L1_loss:0.1586
# Discriminator_loss:0.0894
#
# EPOCH[64] - STEP[250]
# Generator_loss:4.1559
# L1_loss:0.1363
# Discriminator_loss:0.5130
#
# EPOCH[65] - STEP[10]
# Generator_loss:2.8865
# L1_loss:0.1601
# Discriminator_loss:0.2005
#
# EPOCH[65] - STEP[20]
# Generator_loss:2.9122
# L1_loss:0.1309
# Discriminator_loss:0.3338
#
# EPOCH[65] - STEP[30]
# Generator_loss:2.5483
# L1_loss:0.1280
# Discriminator_loss:0.3610
#
# EPOCH[65] - STEP[40]
# Generator_loss:4.3358
# L1_loss:0.1462
# Discriminator_loss:0.0445
#
# EPOCH[65] - STEP[50]
# Generator_loss:5.6112
# L1_loss:0.1465
# Discriminator_loss:0.8068
#
# EPOCH[65] - STEP[60]
# Generator_loss:3.6670
# L1_loss:0.1749
# Discriminator_loss:0.0617
#
# EPOCH[65] - STEP[70]
# Generator_loss:2.0423
# L1_loss:0.1073
# Discriminator_loss:0.4721
#
# EPOCH[65] - STEP[80]
# Generator_loss:1.7616
# L1_loss:0.1336
# Discriminator_loss:0.2899
#
# EPOCH[65] - STEP[90]
# Generator_loss:0.5255
# L1_loss:0.1681
# Discriminator_loss:1.2280
#
# EPOCH[65] - STEP[100]
# Generator_loss:2.5781
# L1_loss:0.1328
# Discriminator_loss:0.2613
#
# EPOCH[65] - STEP[110]
# Generator_loss:3.8359
# L1_loss:0.1408
# Discriminator_loss:0.1684
#
# EPOCH[65] - STEP[120]
# Generator_loss:2.1934
# L1_loss:0.1127
# Discriminator_loss:0.7624
#
# EPOCH[65] - STEP[130]
# Generator_loss:5.3118
# L1_loss:0.1331
# Discriminator_loss:0.9291
#
# EPOCH[65] - STEP[140]
# Generator_loss:5.0377
# L1_loss:0.1546
# Discriminator_loss:0.3489
#
# EPOCH[65] - STEP[150]
# Generator_loss:2.4744
# L1_loss:0.1964
# Discriminator_loss:0.1387
#
# EPOCH[65] - STEP[160]
# Generator_loss:4.4161
# L1_loss:0.1308
# Discriminator_loss:0.0977
#
# EPOCH[65] - STEP[170]
# Generator_loss:1.6875
# L1_loss:0.1113
# Discriminator_loss:0.4402
#
# EPOCH[65] - STEP[180]
# Generator_loss:2.7191
# L1_loss:0.1252
# Discriminator_loss:0.2594
#
# EPOCH[65] - STEP[190]
# Generator_loss:3.0045
# L1_loss:0.1594
# Discriminator_loss:0.2062
#
# EPOCH[65] - STEP[200]
# Generator_loss:6.1339
# L1_loss:0.1217
# Discriminator_loss:1.4307
#
# EPOCH[65] - STEP[210]
# Generator_loss:1.5006
# L1_loss:0.1567
# Discriminator_loss:0.8350
#
# EPOCH[65] - STEP[220]
# Generator_loss:1.5782
# L1_loss:0.1581
# Discriminator_loss:0.7048
#
# EPOCH[65] - STEP[230]
# Generator_loss:2.6615
# L1_loss:0.1234
# Discriminator_loss:0.3071
#
# EPOCH[65] - STEP[240]
# Generator_loss:1.3837
# L1_loss:0.1322
# Discriminator_loss:0.4435
#
# EPOCH[65] - STEP[250]
# Generator_loss:1.0207
# L1_loss:0.1402
# Discriminator_loss:1.2246
#
# EPOCH[66] - STEP[10]
# Generator_loss:3.1075
# L1_loss:0.1381
# Discriminator_loss:0.0830
#
# EPOCH[66] - STEP[20]
# Generator_loss:6.5889
# L1_loss:0.1408
# Discriminator_loss:0.4853
#
# EPOCH[66] - STEP[30]
# Generator_loss:1.5404
# L1_loss:0.1483
# Discriminator_loss:0.4128
#
# EPOCH[66] - STEP[40]
# Generator_loss:2.6821
# L1_loss:0.2231
# Discriminator_loss:0.1122
#
# EPOCH[66] - STEP[50]
# Generator_loss:3.6860
# L1_loss:0.1443
# Discriminator_loss:0.2626
#
# EPOCH[66] - STEP[60]
# Generator_loss:2.3350
# L1_loss:0.1554
# Discriminator_loss:0.4179
#
# EPOCH[66] - STEP[70]
# Generator_loss:2.2381
# L1_loss:0.1396
# Discriminator_loss:0.8272
#
# EPOCH[66] - STEP[80]
# Generator_loss:3.7694
# L1_loss:0.1082
# Discriminator_loss:1.0459
#
# EPOCH[66] - STEP[90]
# Generator_loss:2.3965
# L1_loss:0.1242
# Discriminator_loss:0.2045
#
# EPOCH[66] - STEP[100]
# Generator_loss:3.1028
# L1_loss:0.1915
# Discriminator_loss:0.0899
#
# EPOCH[66] - STEP[110]
# Generator_loss:0.7834
# L1_loss:0.1208
# Discriminator_loss:1.0936
#
# EPOCH[66] - STEP[120]
# Generator_loss:5.0479
# L1_loss:0.1572
# Discriminator_loss:0.0259
#
# EPOCH[66] - STEP[130]
# Generator_loss:2.2662
# L1_loss:0.1069
# Discriminator_loss:0.3028
#
# EPOCH[66] - STEP[140]
# Generator_loss:3.3782
# L1_loss:0.1329
# Discriminator_loss:0.1511
#
# EPOCH[66] - STEP[150]
# Generator_loss:3.1108
# L1_loss:0.1518
# Discriminator_loss:0.1464
#
# EPOCH[66] - STEP[160]
# Generator_loss:3.4876
# L1_loss:0.1473
# Discriminator_loss:0.0820
#
# EPOCH[66] - STEP[170]
# Generator_loss:3.7278
# L1_loss:0.1275
# Discriminator_loss:0.4943
#
# EPOCH[66] - STEP[180]
# Generator_loss:2.1595
# L1_loss:0.1195
# Discriminator_loss:0.3468
#
# EPOCH[66] - STEP[190]
# Generator_loss:3.2234
# L1_loss:0.1328
# Discriminator_loss:0.3373
#
# EPOCH[66] - STEP[200]
# Generator_loss:2.2200
# L1_loss:0.1379
# Discriminator_loss:0.2156
#
# EPOCH[66] - STEP[210]
# Generator_loss:2.4489
# L1_loss:0.1472
# Discriminator_loss:0.2295
#
# EPOCH[66] - STEP[220]
# Generator_loss:1.9529
# L1_loss:0.1227
# Discriminator_loss:0.5690
#
# EPOCH[66] - STEP[230]
# Generator_loss:4.0524
# L1_loss:0.1375
# Discriminator_loss:1.0946
#
# EPOCH[66] - STEP[240]
# Generator_loss:3.2475
# L1_loss:0.1228
# Discriminator_loss:0.1653
#
# EPOCH[66] - STEP[250]
# Generator_loss:1.3722
# L1_loss:0.1268
# Discriminator_loss:0.6294
#
# EPOCH[67] - STEP[10]
# Generator_loss:2.3714
# L1_loss:0.1310
# Discriminator_loss:0.2258
#
# EPOCH[67] - STEP[20]
# Generator_loss:2.4674
# L1_loss:0.1335
# Discriminator_loss:0.5567
#
# EPOCH[67] - STEP[30]
# Generator_loss:5.1254
# L1_loss:0.1554
# Discriminator_loss:0.5606
#
# EPOCH[67] - STEP[40]
# Generator_loss:2.3188
# L1_loss:0.1234
# Discriminator_loss:0.2911
#
# EPOCH[67] - STEP[50]
# Generator_loss:4.9328
# L1_loss:0.1508
# Discriminator_loss:0.3360
#
# EPOCH[67] - STEP[60]
# Generator_loss:1.1545
# L1_loss:0.1203
# Discriminator_loss:0.6736
#
# EPOCH[67] - STEP[70]
# Generator_loss:1.9969
# L1_loss:0.1363
# Discriminator_loss:0.2700
#
# EPOCH[67] - STEP[80]
# Generator_loss:0.6947
# L1_loss:0.1373
# Discriminator_loss:1.2107
#
# EPOCH[67] - STEP[90]
# Generator_loss:3.0786
# L1_loss:0.1483
# Discriminator_loss:0.1428
#
# EPOCH[67] - STEP[100]
# Generator_loss:3.0963
# L1_loss:0.1808
# Discriminator_loss:0.0948
#
# EPOCH[67] - STEP[110]
# Generator_loss:3.2010
# L1_loss:0.1413
# Discriminator_loss:0.8527
#
# EPOCH[67] - STEP[120]
# Generator_loss:4.0078
# L1_loss:0.1255
# Discriminator_loss:0.9799
#
# EPOCH[67] - STEP[130]
# Generator_loss:4.3877
# L1_loss:0.1207
# Discriminator_loss:0.6755
#
# EPOCH[67] - STEP[140]
# Generator_loss:1.6991
# L1_loss:0.1364
# Discriminator_loss:0.3632
#
# EPOCH[67] - STEP[150]
# Generator_loss:2.2234
# L1_loss:0.1475
# Discriminator_loss:0.2951
#
# EPOCH[67] - STEP[160]
# Generator_loss:2.9530
# L1_loss:0.1469
# Discriminator_loss:0.0964
#
# EPOCH[67] - STEP[170]
# Generator_loss:1.0077
# L1_loss:0.1381
# Discriminator_loss:0.9755
#
# EPOCH[67] - STEP[180]
# Generator_loss:0.5625
# L1_loss:0.1373
# Discriminator_loss:1.1601
#
# EPOCH[67] - STEP[190]
# Generator_loss:3.5906
# L1_loss:0.1119
# Discriminator_loss:0.5893
#
# EPOCH[67] - STEP[200]
# Generator_loss:2.4478
# L1_loss:0.1221
# Discriminator_loss:1.2843
#
# EPOCH[67] - STEP[210]
# Generator_loss:4.5063
# L1_loss:0.1482
# Discriminator_loss:0.2705
#
# EPOCH[67] - STEP[220]
# Generator_loss:0.8096
# L1_loss:0.1549
# Discriminator_loss:0.9953
#
# EPOCH[67] - STEP[230]
# Generator_loss:0.9669
# L1_loss:0.1155
# Discriminator_loss:1.0853
#
# EPOCH[67] - STEP[240]
# Generator_loss:1.1986
# L1_loss:0.1323
# Discriminator_loss:0.6624
#
# EPOCH[67] - STEP[250]
# Generator_loss:3.5226
# L1_loss:0.1196
# Discriminator_loss:0.3194
#
# EPOCH[68] - STEP[10]
# Generator_loss:5.5957
# L1_loss:0.1663
# Discriminator_loss:0.0447
#
# EPOCH[68] - STEP[20]
# Generator_loss:4.3328
# L1_loss:0.1224
# Discriminator_loss:1.1547
#
# EPOCH[68] - STEP[30]
# Generator_loss:3.0090
# L1_loss:0.1466
# Discriminator_loss:0.3639
#
# EPOCH[68] - STEP[40]
# Generator_loss:2.5530
# L1_loss:0.1447
# Discriminator_loss:0.2364
#
# EPOCH[68] - STEP[50]
# Generator_loss:0.5644
# L1_loss:0.1399
# Discriminator_loss:1.4971
#
# EPOCH[68] - STEP[60]
# Generator_loss:3.8887
# L1_loss:0.1120
# Discriminator_loss:0.2955
#
# EPOCH[68] - STEP[70]
# Generator_loss:2.0091
# L1_loss:0.1342
# Discriminator_loss:0.2336
#
# EPOCH[68] - STEP[80]
# Generator_loss:1.7861
# L1_loss:0.1155
# Discriminator_loss:0.3502
#
# EPOCH[68] - STEP[90]
# Generator_loss:1.3364
# L1_loss:0.1741
# Discriminator_loss:0.4453
#
# EPOCH[68] - STEP[100]
# Generator_loss:1.6150
# L1_loss:0.1363
# Discriminator_loss:0.4298
#
# EPOCH[68] - STEP[110]
# Generator_loss:2.2260
# L1_loss:0.1495
# Discriminator_loss:0.1830
#
# EPOCH[68] - STEP[120]
# Generator_loss:3.7909
# L1_loss:0.1208
# Discriminator_loss:1.0025
#
# EPOCH[68] - STEP[130]
# Generator_loss:2.8736
# L1_loss:0.1311
# Discriminator_loss:0.1811
#
# EPOCH[68] - STEP[140]
# Generator_loss:1.5075
# L1_loss:0.1322
# Discriminator_loss:0.3764
#
# EPOCH[68] - STEP[150]
# Generator_loss:2.1836
# L1_loss:0.1812
# Discriminator_loss:0.1996
#
# EPOCH[68] - STEP[160]
# Generator_loss:2.1811
# L1_loss:0.1175
# Discriminator_loss:0.3575
#
# EPOCH[68] - STEP[170]
# Generator_loss:1.8183
# L1_loss:0.1487
# Discriminator_loss:0.6517
#
# EPOCH[68] - STEP[180]
# Generator_loss:2.2307
# L1_loss:0.1416
# Discriminator_loss:0.5134
#
# EPOCH[68] - STEP[190]
# Generator_loss:5.0772
# L1_loss:0.1482
# Discriminator_loss:0.1150
#
# EPOCH[68] - STEP[200]
# Generator_loss:1.3923
# L1_loss:0.1285
# Discriminator_loss:0.5702
#
# EPOCH[68] - STEP[210]
# Generator_loss:4.5832
# L1_loss:0.1335
# Discriminator_loss:0.2554
#
# EPOCH[68] - STEP[220]
# Generator_loss:1.6451
# L1_loss:0.1684
# Discriminator_loss:0.3523
#
# EPOCH[68] - STEP[230]
# Generator_loss:4.2754
# L1_loss:0.1477
# Discriminator_loss:0.0662
#
# EPOCH[68] - STEP[240]
# Generator_loss:1.5131
# L1_loss:0.1403
# Discriminator_loss:0.7703
#
# EPOCH[68] - STEP[250]
# Generator_loss:2.8708
# L1_loss:0.1190
# Discriminator_loss:0.7222
#
# EPOCH[69] - STEP[10]
# Generator_loss:3.3751
# L1_loss:0.1155
# Discriminator_loss:0.1645
#
# EPOCH[69] - STEP[20]
# Generator_loss:1.9099
# L1_loss:0.1262
# Discriminator_loss:0.3879
#
# EPOCH[69] - STEP[30]
# Generator_loss:3.3785
# L1_loss:0.1140
# Discriminator_loss:0.1519
#
# EPOCH[69] - STEP[40]
# Generator_loss:2.3383
# L1_loss:0.1746
# Discriminator_loss:0.1966
#
# EPOCH[69] - STEP[50]
# Generator_loss:1.9689
# L1_loss:0.1423
# Discriminator_loss:0.2563
#
# EPOCH[69] - STEP[60]
# Generator_loss:3.2649
# L1_loss:0.1285
# Discriminator_loss:0.3241
#
# EPOCH[69] - STEP[70]
# Generator_loss:2.5643
# L1_loss:0.1115
# Discriminator_loss:0.4902
#
# EPOCH[69] - STEP[80]
# Generator_loss:3.3951
# L1_loss:0.1170
# Discriminator_loss:0.1148
#
# EPOCH[69] - STEP[90]
# Generator_loss:1.7052
# L1_loss:0.1636
# Discriminator_loss:0.4949
#
# EPOCH[69] - STEP[100]
# Generator_loss:2.5988
# L1_loss:0.1167
# Discriminator_loss:0.4414
#
# EPOCH[69] - STEP[110]
# Generator_loss:1.7572
# L1_loss:0.1382
# Discriminator_loss:0.4397
#
# EPOCH[69] - STEP[120]
# Generator_loss:2.5286
# L1_loss:0.1223
# Discriminator_loss:0.2940
#
# EPOCH[69] - STEP[130]
# Generator_loss:4.5557
# L1_loss:0.1675
# Discriminator_loss:0.1864
#
# EPOCH[69] - STEP[140]
# Generator_loss:2.1361
# L1_loss:0.1386
# Discriminator_loss:0.2983
#
# EPOCH[69] - STEP[150]
# Generator_loss:3.3391
# L1_loss:0.1414
# Discriminator_loss:0.4942
#
# EPOCH[69] - STEP[160]
# Generator_loss:4.9537
# L1_loss:0.1196
# Discriminator_loss:1.4225
#
# EPOCH[69] - STEP[170]
# Generator_loss:3.6629
# L1_loss:0.1391
# Discriminator_loss:0.7265
#
# EPOCH[69] - STEP[180]
# Generator_loss:2.2245
# L1_loss:0.1522
# Discriminator_loss:0.3080
#
# EPOCH[69] - STEP[190]
# Generator_loss:1.9034
# L1_loss:0.1401
# Discriminator_loss:0.2768
#
# EPOCH[69] - STEP[200]
# Generator_loss:1.9334
# L1_loss:0.1225
# Discriminator_loss:0.2857
#
# EPOCH[69] - STEP[210]
# Generator_loss:4.1598
# L1_loss:0.1450
# Discriminator_loss:1.5092
#
# EPOCH[69] - STEP[220]
# Generator_loss:3.1175
# L1_loss:0.1587
# Discriminator_loss:0.0964
#
# EPOCH[69] - STEP[230]
# Generator_loss:2.3739
# L1_loss:0.1530
# Discriminator_loss:0.2494
#
# EPOCH[69] - STEP[240]
# Generator_loss:4.0561
# L1_loss:0.1724
# Discriminator_loss:0.4025
#
# EPOCH[69] - STEP[250]
# Generator_loss:1.8268
# L1_loss:0.1725
# Discriminator_loss:0.2930
#
# EPOCH[70] - STEP[10]
# Generator_loss:3.1697
# L1_loss:0.1272
# Discriminator_loss:0.1176
#
# EPOCH[70] - STEP[20]
# Generator_loss:2.1434
# L1_loss:0.1168
# Discriminator_loss:0.2735
#
# EPOCH[70] - STEP[30]
# Generator_loss:3.6476
# L1_loss:0.1344
# Discriminator_loss:0.1714
#
# EPOCH[70] - STEP[40]
# Generator_loss:1.6013
# L1_loss:0.1378
# Discriminator_loss:0.3946
#
# EPOCH[70] - STEP[50]
# Generator_loss:2.2623
# L1_loss:0.1719
# Discriminator_loss:0.1549
#
# EPOCH[70] - STEP[60]
# Generator_loss:2.9392
# L1_loss:0.1666
# Discriminator_loss:0.1106
#
# EPOCH[70] - STEP[70]
# Generator_loss:5.2911
# L1_loss:0.1587
# Discriminator_loss:0.7100
#
# EPOCH[70] - STEP[80]
# Generator_loss:2.1963
# L1_loss:0.1222
# Discriminator_loss:0.3210
#
# EPOCH[70] - STEP[90]
# Generator_loss:1.9962
# L1_loss:0.1329
# Discriminator_loss:0.3233
#
# EPOCH[70] - STEP[100]
# Generator_loss:2.8105
# L1_loss:0.1418
# Discriminator_loss:1.3063
#
# EPOCH[70] - STEP[110]
# Generator_loss:3.7857
# L1_loss:0.1982
# Discriminator_loss:0.1542
#
# EPOCH[70] - STEP[120]
# Generator_loss:3.8548
# L1_loss:0.1172
# Discriminator_loss:1.0807
#
# EPOCH[70] - STEP[130]
# Generator_loss:5.3771
# L1_loss:0.1643
# Discriminator_loss:0.0349
#
# EPOCH[70] - STEP[140]
# Generator_loss:3.3218
# L1_loss:0.1439
# Discriminator_loss:0.0754
#
# EPOCH[70] - STEP[150]
# Generator_loss:5.0725
# L1_loss:0.1299
# Discriminator_loss:1.1320
#
# EPOCH[70] - STEP[160]
# Generator_loss:0.8558
# L1_loss:0.1908
# Discriminator_loss:0.8074
#
# EPOCH[70] - STEP[170]
# Generator_loss:1.4563
# L1_loss:0.1330
# Discriminator_loss:0.5806
#
# EPOCH[70] - STEP[180]
# Generator_loss:4.9871
# L1_loss:0.1394
# Discriminator_loss:0.5723
#
# EPOCH[70] - STEP[190]
# Generator_loss:3.1492
# L1_loss:0.1363
# Discriminator_loss:0.8954
#
# EPOCH[70] - STEP[200]
# Generator_loss:1.0340
# L1_loss:0.1716
# Discriminator_loss:0.6998
#
# EPOCH[70] - STEP[210]
# Generator_loss:3.1438
# L1_loss:0.1801
# Discriminator_loss:0.1900
#
# EPOCH[70] - STEP[220]
# Generator_loss:2.3843
# L1_loss:0.1629
# Discriminator_loss:0.2262
#
# EPOCH[70] - STEP[230]
# Generator_loss:2.5137
# L1_loss:0.1093
# Discriminator_loss:0.3580
#
# EPOCH[70] - STEP[240]
# Generator_loss:3.4673
# L1_loss:0.1087
# Discriminator_loss:0.8733
#
# EPOCH[70] - STEP[250]
# Generator_loss:5.1024
# L1_loss:0.1581
# Discriminator_loss:0.6670
#
# EPOCH[71] - STEP[10]
# Generator_loss:0.9084
# L1_loss:0.1431
# Discriminator_loss:0.7566
#
# EPOCH[71] - STEP[20]
# Generator_loss:1.9745
# L1_loss:0.1343
# Discriminator_loss:0.3429
#
# EPOCH[71] - STEP[30]
# Generator_loss:2.3613
# L1_loss:0.1340
# Discriminator_loss:0.4630
#
# EPOCH[71] - STEP[40]
# Generator_loss:5.5854
# L1_loss:0.1546
# Discriminator_loss:0.2971
#
# EPOCH[71] - STEP[50]
# Generator_loss:0.9539
# L1_loss:0.1164
# Discriminator_loss:1.1866
#
# EPOCH[71] - STEP[60]
# Generator_loss:2.6827
# L1_loss:0.1094
# Discriminator_loss:0.4219
#
# EPOCH[71] - STEP[70]
# Generator_loss:4.2231
# L1_loss:0.1649
# Discriminator_loss:0.2564
#
# EPOCH[71] - STEP[80]
# Generator_loss:1.0053
# L1_loss:0.1368
# Discriminator_loss:0.8975
#
# EPOCH[71] - STEP[90]
# Generator_loss:4.0919
# L1_loss:0.1457
# Discriminator_loss:0.4631
#
# EPOCH[71] - STEP[100]
# Generator_loss:1.2563
# L1_loss:0.1205
# Discriminator_loss:1.0690
#
# EPOCH[71] - STEP[110]
# Generator_loss:2.8071
# L1_loss:0.1344
# Discriminator_loss:0.2952
#
# EPOCH[71] - STEP[120]
# Generator_loss:3.7287
# L1_loss:0.1782
# Discriminator_loss:0.0752
#
# EPOCH[71] - STEP[130]
# Generator_loss:4.1254
# L1_loss:0.1519
# Discriminator_loss:1.0497
#
# EPOCH[71] - STEP[140]
# Generator_loss:3.3510
# L1_loss:0.1451
# Discriminator_loss:0.3119
#
# EPOCH[71] - STEP[150]
# Generator_loss:3.3308
# L1_loss:0.1479
# Discriminator_loss:0.4532
#
# EPOCH[71] - STEP[160]
# Generator_loss:3.3173
# L1_loss:0.1310
# Discriminator_loss:0.1946
#
# EPOCH[71] - STEP[170]
# Generator_loss:3.2463
# L1_loss:0.1327
# Discriminator_loss:0.2005
#
# EPOCH[71] - STEP[180]
# Generator_loss:3.3697
# L1_loss:0.1491
# Discriminator_loss:0.1232
#
# EPOCH[71] - STEP[190]
# Generator_loss:0.8875
# L1_loss:0.1226
# Discriminator_loss:0.8511
#
# EPOCH[71] - STEP[200]
# Generator_loss:2.6983
# L1_loss:0.1323
# Discriminator_loss:0.1677
#
# EPOCH[71] - STEP[210]
# Generator_loss:2.9453
# L1_loss:0.1345
# Discriminator_loss:0.2884
#
# EPOCH[71] - STEP[220]
# Generator_loss:4.5551
# L1_loss:0.1477
# Discriminator_loss:0.7201
#
# EPOCH[71] - STEP[230]
# Generator_loss:1.8788
# L1_loss:0.1611
# Discriminator_loss:0.3616
#
# EPOCH[71] - STEP[240]
# Generator_loss:2.7308
# L1_loss:0.1359
# Discriminator_loss:0.2045
#
# EPOCH[71] - STEP[250]
# Generator_loss:1.9148
# L1_loss:0.1680
# Discriminator_loss:0.6756
#
# EPOCH[72] - STEP[10]
# Generator_loss:2.5793
# L1_loss:0.1323
# Discriminator_loss:0.1678
#
# EPOCH[72] - STEP[20]
# Generator_loss:2.7210
# L1_loss:0.1513
# Discriminator_loss:0.1165
#
# EPOCH[72] - STEP[30]
# Generator_loss:2.5165
# L1_loss:0.1398
# Discriminator_loss:0.1511
#
# EPOCH[72] - STEP[40]
# Generator_loss:2.3136
# L1_loss:0.1226
# Discriminator_loss:0.2167
#
# EPOCH[72] - STEP[50]
# Generator_loss:2.5102
# L1_loss:0.1479
# Discriminator_loss:0.1929
#
# EPOCH[72] - STEP[60]
# Generator_loss:1.6306
# L1_loss:0.1337
# Discriminator_loss:0.2916
#
# EPOCH[72] - STEP[70]
# Generator_loss:3.2762
# L1_loss:0.1266
# Discriminator_loss:0.3206
#
# EPOCH[72] - STEP[80]
# Generator_loss:4.6540
# L1_loss:0.1338
# Discriminator_loss:0.1264
#
# EPOCH[72] - STEP[90]
# Generator_loss:3.1040
# L1_loss:0.1485
# Discriminator_loss:0.0722
#
# EPOCH[72] - STEP[100]
# Generator_loss:3.0764
# L1_loss:0.1366
# Discriminator_loss:0.6987
#
# EPOCH[72] - STEP[110]
# Generator_loss:2.1240
# L1_loss:0.1857
# Discriminator_loss:0.2544
#
# EPOCH[72] - STEP[120]
# Generator_loss:5.5243
# L1_loss:0.1673
# Discriminator_loss:0.1136
#
# EPOCH[72] - STEP[130]
# Generator_loss:2.6816
# L1_loss:0.1432
# Discriminator_loss:1.5720
#
# EPOCH[72] - STEP[140]
# Generator_loss:3.5603
# L1_loss:0.1293
# Discriminator_loss:0.2199
#
# EPOCH[72] - STEP[150]
# Generator_loss:0.9630
# L1_loss:0.1223
# Discriminator_loss:0.9098
#
# EPOCH[72] - STEP[160]
# Generator_loss:1.3683
# L1_loss:0.1312
# Discriminator_loss:0.9217
#
# EPOCH[72] - STEP[170]
# Generator_loss:2.7336
# L1_loss:0.1347
# Discriminator_loss:0.4609
#
# EPOCH[72] - STEP[180]
# Generator_loss:2.8216
# L1_loss:0.1583
# Discriminator_loss:0.1630
#
# EPOCH[72] - STEP[190]
# Generator_loss:6.0900
# L1_loss:0.1258
# Discriminator_loss:0.1785
#
# EPOCH[72] - STEP[200]
# Generator_loss:4.1323
# L1_loss:0.1318
# Discriminator_loss:0.6516
#
# EPOCH[72] - STEP[210]
# Generator_loss:3.7279
# L1_loss:0.1404
# Discriminator_loss:0.1171
#
# EPOCH[72] - STEP[220]
# Generator_loss:1.6753
# L1_loss:0.1388
# Discriminator_loss:0.3839
#
# EPOCH[72] - STEP[230]
# Generator_loss:2.4414
# L1_loss:0.1444
# Discriminator_loss:0.1818
#
# EPOCH[72] - STEP[240]
# Generator_loss:3.3756
# L1_loss:0.1324
# Discriminator_loss:1.0960
#
# EPOCH[72] - STEP[250]
# Generator_loss:3.4780
# L1_loss:0.1563
# Discriminator_loss:0.0950
#
# EPOCH[73] - STEP[10]
# Generator_loss:2.8113
# L1_loss:0.1266
# Discriminator_loss:0.2734
#
# EPOCH[73] - STEP[20]
# Generator_loss:2.9797
# L1_loss:0.1586
# Discriminator_loss:0.1779
#
# EPOCH[73] - STEP[30]
# Generator_loss:2.8631
# L1_loss:0.1511
# Discriminator_loss:0.1108
#
# EPOCH[73] - STEP[40]
# Generator_loss:2.9379
# L1_loss:0.1541
# Discriminator_loss:0.1702
#
# EPOCH[73] - STEP[50]
# Generator_loss:0.9261
# L1_loss:0.1125
# Discriminator_loss:1.1775
#
# EPOCH[73] - STEP[60]
# Generator_loss:0.9488
# L1_loss:0.1156
# Discriminator_loss:0.7541
#
# EPOCH[73] - STEP[70]
# Generator_loss:3.9956
# L1_loss:0.1212
# Discriminator_loss:0.3164
#
# EPOCH[73] - STEP[80]
# Generator_loss:4.1768
# L1_loss:0.1542
# Discriminator_loss:0.1148
#
# EPOCH[73] - STEP[90]
# Generator_loss:3.2084
# L1_loss:0.1368
# Discriminator_loss:0.2513
#
# EPOCH[73] - STEP[100]
# Generator_loss:1.7049
# L1_loss:0.1388
# Discriminator_loss:0.3589
#
# EPOCH[73] - STEP[110]
# Generator_loss:4.9417
# L1_loss:0.1367
# Discriminator_loss:0.4371
#
# EPOCH[73] - STEP[120]
# Generator_loss:3.8099
# L1_loss:0.1128
# Discriminator_loss:0.2969
#
# EPOCH[73] - STEP[130]
# Generator_loss:4.8532
# L1_loss:0.1065
# Discriminator_loss:1.8949
#
# EPOCH[73] - STEP[140]
# Generator_loss:3.5717
# L1_loss:0.1362
# Discriminator_loss:0.1753
#
# EPOCH[73] - STEP[150]
# Generator_loss:5.2962
# L1_loss:0.1511
# Discriminator_loss:0.3945
#
# EPOCH[73] - STEP[160]
# Generator_loss:1.6140
# L1_loss:0.1303
# Discriminator_loss:0.3930
#
# EPOCH[73] - STEP[170]
# Generator_loss:1.3043
# L1_loss:0.1269
# Discriminator_loss:0.5713
#
# EPOCH[73] - STEP[180]
# Generator_loss:3.4372
# L1_loss:0.1410
# Discriminator_loss:0.1092
#
# EPOCH[73] - STEP[190]
# Generator_loss:1.6164
# L1_loss:0.1610
# Discriminator_loss:0.4040
#
# EPOCH[73] - STEP[200]
# Generator_loss:3.6977
# L1_loss:0.1092
# Discriminator_loss:0.7975
#
# EPOCH[73] - STEP[210]
# Generator_loss:3.9715
# L1_loss:0.1378
# Discriminator_loss:0.0861
#
# EPOCH[73] - STEP[220]
# Generator_loss:4.0590
# L1_loss:0.1129
# Discriminator_loss:0.3776
#
# EPOCH[73] - STEP[230]
# Generator_loss:0.6623
# ...
# L1_loss:0.1315
# Discriminator_loss:0.1091
#
# EPOCH[96] - STEP[190]
# Generator_loss:4.0714
# L1_loss:0.1295
# Discriminator_loss:0.1697
#
# EPOCH[96] - STEP[200]
# Generator_loss:3.3645
# L1_loss:0.1033
# Discriminator_loss:0.4135
#
# EPOCH[96] - STEP[210]
# Generator_loss:1.0215
# L1_loss:0.1234
# Discriminator_loss:1.0366
#
# EPOCH[96] - STEP[220]
# Generator_loss:1.1632
# L1_loss:0.1351
# Discriminator_loss:0.6079
#
# EPOCH[96] - STEP[230]
# Generator_loss:5.1871
# L1_loss:0.1108
# Discriminator_loss:0.2558
#
# EPOCH[96] - STEP[240]
# Generator_loss:1.4398
# L1_loss:0.1696
# Discriminator_loss:0.4025
#
# EPOCH[96] - STEP[250]
# Generator_loss:4.1623
# L1_loss:0.1367
# Discriminator_loss:0.1099
#
# EPOCH[97] - STEP[10]
# Generator_loss:2.7615
# L1_loss:0.1232
# Discriminator_loss:0.1752
#
# EPOCH[97] - STEP[20]
# Generator_loss:2.7388
# L1_loss:0.1635
# Discriminator_loss:0.1695
#
# EPOCH[97] - STEP[30]
# Generator_loss:3.2147
# L1_loss:0.1288
# Discriminator_loss:0.1133
#
# EPOCH[97] - STEP[40]
# Generator_loss:3.2397
# L1_loss:0.1492
# Discriminator_loss:0.1683
#
# EPOCH[97] - STEP[50]
# Generator_loss:1.8480
# L1_loss:0.1265
# Discriminator_loss:0.3128
#
# EPOCH[97] - STEP[60]
# Generator_loss:1.8422
# L1_loss:0.1109
# Discriminator_loss:0.4762
#
# EPOCH[97] - STEP[70]
# Generator_loss:2.7064
# L1_loss:0.1232
# Discriminator_loss:1.2386
#
# EPOCH[97] - STEP[80]
# Generator_loss:4.6472
# L1_loss:0.1324
# Discriminator_loss:0.8511
#
# EPOCH[97] - STEP[90]
# Generator_loss:1.8852
# L1_loss:0.1422
# Discriminator_loss:0.4660
#
# EPOCH[97] - STEP[100]
# Generator_loss:4.1959
# L1_loss:0.1214
# Discriminator_loss:0.2203
#
# EPOCH[97] - STEP[110]
# Generator_loss:3.8249
# L1_loss:0.1126
# Discriminator_loss:0.4995
#
# EPOCH[97] - STEP[120]
# Generator_loss:3.1002
# L1_loss:0.1420
# Discriminator_loss:0.0903
#
# EPOCH[97] - STEP[130]
# Generator_loss:3.6503
# L1_loss:0.1158
# Discriminator_loss:1.0555
#
# EPOCH[97] - STEP[140]
# Generator_loss:4.6540
# L1_loss:0.1228
# Discriminator_loss:1.6848
#
# EPOCH[97] - STEP[150]
# Generator_loss:3.3460
# L1_loss:0.1300
# Discriminator_loss:0.3544
#
# EPOCH[97] - STEP[160]
# Generator_loss:1.9129
# L1_loss:0.1568
# Discriminator_loss:0.7258
#
# EPOCH[97] - STEP[170]
# Generator_loss:3.8474
# L1_loss:0.1240
# Discriminator_loss:0.1476
#
# EPOCH[97] - STEP[180]
# Generator_loss:0.1216
# L1_loss:0.1491
# Discriminator_loss:2.7455
#
# EPOCH[97] - STEP[190]
# Generator_loss:3.6503
# L1_loss:0.1038
# Discriminator_loss:0.9866
#
# EPOCH[97] - STEP[200]
# Generator_loss:2.6616
# L1_loss:0.1302
# Discriminator_loss:0.2150
#
# EPOCH[97] - STEP[210]
# Generator_loss:3.1775
# L1_loss:0.1356
# Discriminator_loss:0.1194
#
# EPOCH[97] - STEP[220]
# Generator_loss:4.7917
# L1_loss:0.1220
# Discriminator_loss:0.1675
#
# EPOCH[97] - STEP[230]
# Generator_loss:2.0374
# L1_loss:0.1153
# Discriminator_loss:0.3394
#
# EPOCH[97] - STEP[240]
# Generator_loss:2.4087
# L1_loss:0.1300
# Discriminator_loss:0.2487
#
# EPOCH[97] - STEP[250]
# Generator_loss:1.8482
# L1_loss:0.1615
# Discriminator_loss:0.2702
#
# EPOCH[98] - STEP[10]
# Generator_loss:3.1344
# L1_loss:0.1335
# Discriminator_loss:0.2322
#
# EPOCH[98] - STEP[20]
# Generator_loss:2.1041
# L1_loss:0.1089
# Discriminator_loss:0.3945
#
# EPOCH[98] - STEP[30]
# Generator_loss:2.6287
# L1_loss:0.1545
# Discriminator_loss:0.4386
#
# EPOCH[98] - STEP[40]
# Generator_loss:2.5077
# L1_loss:0.1226
# Discriminator_loss:0.2960
#
# EPOCH[98] - STEP[50]
# Generator_loss:3.1426
# L1_loss:0.1434
# Discriminator_loss:0.3155
#
# EPOCH[98] - STEP[60]
# Generator_loss:3.2288
# L1_loss:0.1274
# Discriminator_loss:0.1026
#
# EPOCH[98] - STEP[70]
# Generator_loss:2.6834
# L1_loss:0.1509
# Discriminator_loss:0.1653
#
# EPOCH[98] - STEP[80]
# Generator_loss:3.4990
# L1_loss:0.1306
# Discriminator_loss:0.7330
#
# EPOCH[98] - STEP[90]
# Generator_loss:2.1816
# L1_loss:0.1339
# Discriminator_loss:0.2171
#
# EPOCH[98] - STEP[100]
# Generator_loss:1.4476
# L1_loss:0.1352
# Discriminator_loss:0.5869
#
# EPOCH[98] - STEP[110]
# Generator_loss:4.1635
# L1_loss:0.1259
# Discriminator_loss:0.5496
#
# EPOCH[98] - STEP[120]
# Generator_loss:4.3236
# L1_loss:0.1071
# Discriminator_loss:1.0875
#
# EPOCH[98] - STEP[130]
# Generator_loss:2.5971
# L1_loss:0.1316
# Discriminator_loss:0.3520
#
# EPOCH[98] - STEP[140]
# Generator_loss:3.0013
# L1_loss:0.1101
# Discriminator_loss:0.2520
#
# EPOCH[98] - STEP[150]
# Generator_loss:3.6182
# L1_loss:0.1566
# Discriminator_loss:0.3880
#
# EPOCH[98] - STEP[160]
# Generator_loss:3.8841
# L1_loss:0.1173
# Discriminator_loss:1.1007
#
# EPOCH[98] - STEP[170]
# Generator_loss:4.1444
# L1_loss:0.0950
# Discriminator_loss:0.4484
#
# EPOCH[98] - STEP[180]
# Generator_loss:4.2425
# L1_loss:0.1330
# Discriminator_loss:0.3624
#
# EPOCH[98] - STEP[190]
# Generator_loss:3.6198
# L1_loss:0.1064
# Discriminator_loss:0.2452
#
# EPOCH[98] - STEP[200]
# Generator_loss:0.3504
# L1_loss:0.1229
# Discriminator_loss:1.6942
#
# EPOCH[98] - STEP[210]
# Generator_loss:2.4780
# L1_loss:0.1043
# Discriminator_loss:0.3568
#
# EPOCH[98] - STEP[220]
# Generator_loss:2.2443
# L1_loss:0.1433
# Discriminator_loss:0.2116
#
# EPOCH[98] - STEP[230]
# Generator_loss:3.1453
# L1_loss:0.1464
# Discriminator_loss:0.1037
#
# EPOCH[98] - STEP[240]
# Generator_loss:2.9441
# L1_loss:0.1278
# Discriminator_loss:0.2270
#
# EPOCH[98] - STEP[250]
# Generator_loss:2.3007
# L1_loss:0.1372
# Discriminator_loss:0.3991
#
# EPOCH[99] - STEP[10]
# Generator_loss:4.9274
# L1_loss:0.1176
# Discriminator_loss:0.2638
#
# EPOCH[99] - STEP[20]
# Generator_loss:3.0412
# L1_loss:0.1243
# Discriminator_loss:0.1197
#
# EPOCH[99] - STEP[30]
# Generator_loss:2.9518
# L1_loss:0.1464
# Discriminator_loss:0.1168
#
# EPOCH[99] - STEP[40]
# Generator_loss:0.4891
# L1_loss:0.1283
# Discriminator_loss:1.4744
#
# EPOCH[99] - STEP[50]
# Generator_loss:3.9998
# L1_loss:0.1257
# Discriminator_loss:0.1561
#
# EPOCH[99] - STEP[60]
# Generator_loss:3.1172
# L1_loss:0.1397
# Discriminator_loss:0.5534
#
# EPOCH[99] - STEP[70]
# Generator_loss:4.6488
# L1_loss:0.1395
# Discriminator_loss:0.4969
#
# EPOCH[99] - STEP[80]
# Generator_loss:4.4131
# L1_loss:0.1220
# Discriminator_loss:0.4622
#
# EPOCH[99] - STEP[90]
# Generator_loss:1.1371
# L1_loss:0.1104
# Discriminator_loss:0.7861
#
# EPOCH[99] - STEP[100]
# Generator_loss:5.4410
# L1_loss:0.1549
# Discriminator_loss:0.0672
#
# EPOCH[99] - STEP[110]
# Generator_loss:3.9058
# L1_loss:0.1051
# Discriminator_loss:0.1339
#
# EPOCH[99] - STEP[120]
# Generator_loss:4.3107
# L1_loss:0.1660
# Discriminator_loss:0.0705
#
# EPOCH[99] - STEP[130]
# Generator_loss:1.5371
# L1_loss:0.1187
# Discriminator_loss:0.5387
#
# EPOCH[99] - STEP[140]
# Generator_loss:3.3274
# L1_loss:0.1337
# Discriminator_loss:0.3152
#
# EPOCH[99] - STEP[150]
# Generator_loss:2.0612
# L1_loss:0.1166
# Discriminator_loss:0.3842
#
# EPOCH[99] - STEP[160]
# Generator_loss:3.5203
# L1_loss:0.1031
# Discriminator_loss:0.2981
#
# EPOCH[99] - STEP[170]
# Generator_loss:3.9975
# L1_loss:0.1466
# Discriminator_loss:0.2087
#
# EPOCH[99] - STEP[180]
# Generator_loss:1.2469
# L1_loss:0.1034
# Discriminator_loss:0.6080
#
# EPOCH[99] - STEP[190]
# Generator_loss:2.0173
# L1_loss:0.1241
# Discriminator_loss:0.4957
#
# EPOCH[99] - STEP[200]
# Generator_loss:4.2235
# L1_loss:0.1313
# Discriminator_loss:0.2673
#
# EPOCH[99] - STEP[210]
# Generator_loss:1.8277
# L1_loss:0.1440
# Discriminator_loss:0.2981
#
# EPOCH[99] - STEP[220]
# Generator_loss:2.9661
# L1_loss:0.1222
# Discriminator_loss:0.1880
#
# EPOCH[99] - STEP[230]
# Generator_loss:2.3604
# L1_loss:0.1353
# Discriminator_loss:0.2655
#
# EPOCH[99] - STEP[240]
# Generator_loss:3.2097
# L1_loss:0.1526
# Discriminator_loss:0.1065
#
# EPOCH[99] - STEP[250]
# Generator_loss:2.1665
# L1_loss:0.1262
# Discriminator_loss:0.2738
#
# EPOCH[100] - STEP[10]
# Generator_loss:1.3070
# L1_loss:0.1342
# Discriminator_loss:0.4750
#
# EPOCH[100] - STEP[20]
# Generator_loss:4.6250
# L1_loss:0.1517
# Discriminator_loss:0.1513
#
# EPOCH[100] - STEP[30]
# Generator_loss:2.0211
# L1_loss:0.1573
# Discriminator_loss:0.2342
#
# EPOCH[100] - STEP[40]
# Generator_loss:3.6684
# L1_loss:0.1418
# Discriminator_loss:0.0675
#
# EPOCH[100] - STEP[50]
# Generator_loss:3.2863
# L1_loss:0.1306
# Discriminator_loss:0.1376
#
# EPOCH[100] - STEP[60]
# Generator_loss:1.3073
# L1_loss:0.1512
# Discriminator_loss:0.5852
#
# EPOCH[100] - STEP[70]
# Generator_loss:0.7891
# L1_loss:0.1366
# Discriminator_loss:0.9270
#
# EPOCH[100] - STEP[80]
# Generator_loss:0.8994
# L1_loss:0.1852
# Discriminator_loss:1.1074
#
# EPOCH[100] - STEP[90]
# Generator_loss:4.1013
# L1_loss:0.1396
# Discriminator_loss:0.2735
#
# EPOCH[100] - STEP[100]
# Generator_loss:4.4246
# L1_loss:0.1235
# Discriminator_loss:0.0700
#
# EPOCH[100] - STEP[110]
# Generator_loss:4.6585
# L1_loss:0.1509
# Discriminator_loss:0.0326
#
# EPOCH[100] - STEP[120]
# Generator_loss:2.7505
# L1_loss:0.1312
# Discriminator_loss:0.3751
#
# EPOCH[100] - STEP[130]
# Generator_loss:4.7995
# L1_loss:0.1346
# Discriminator_loss:0.1635
#
# EPOCH[100] - STEP[140]
# Generator_loss:3.8708
# L1_loss:0.1497
# Discriminator_loss:0.0609
#
# EPOCH[100] - STEP[150]
# Generator_loss:2.6147
# L1_loss:0.1237
# Discriminator_loss:0.2180
#
# EPOCH[100] - STEP[160]
# Generator_loss:3.3237
# L1_loss:0.1172
# Discriminator_loss:0.2574
#
# EPOCH[100] - STEP[170]
# Generator_loss:1.7281
# L1_loss:0.1257
# Discriminator_loss:0.3741
#
# EPOCH[100] - STEP[180]
# Generator_loss:2.6952
# L1_loss:0.1248
# Discriminator_loss:0.1548
#
# EPOCH[100] - STEP[190]
# Generator_loss:0.9887
# L1_loss:0.1207
# Discriminator_loss:1.1193
#
# EPOCH[100] - STEP[200]
# Generator_loss:5.3389
# L1_loss:0.1240
# Discriminator_loss:0.0857
#
# EPOCH[100] - STEP[210]
# Generator_loss:1.1233
# L1_loss:0.1275
# Discriminator_loss:0.9245
#
# EPOCH[100] - STEP[220]
# Generator_loss:4.8993
# L1_loss:0.1557
# Discriminator_loss:0.1321
#
# EPOCH[100] - STEP[230]
# Generator_loss:3.5251
# L1_loss:0.1426
# Discriminator_loss:0.0814
#
# EPOCH[100] - STEP[240]
# Generator_loss:3.9961
# L1_loss:0.1354
# Discriminator_loss:0.0611
#
# EPOCH[100] - STEP[250]
# Generator_loss:0.8469
# L1_loss:0.1406
# Discriminator_loss:1.0749

# %%
f = val[0]
sketch, colored = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))

# %% [markdown]
# * 회고
#   * cGAN에 대한 전체적인 흐름은 흥미로운 점이 많았다.
#   * 구체적인 코드 구현은 항상 그렇지만 너무 어렵다.. 코드 구현 능력과 논문 해석, 이론을 코드로 구현하는 부분에서 방향을 잃은 기분...
#   * 기초부터 다시 돌아가서 복기 해보는 것이 필요할 것 같다.
#   * 노드의 내용과 다른 분이 작성하신 것을 참고해 진행했을 때, 생성된 이미지의 퀄리티는 좋은 것 같다.
